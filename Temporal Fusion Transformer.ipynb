# %%
import os
import warnings

warnings.filterwarnings('ignore')

# %%
import copy
from pathlib import Path
import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# %%
torch.version.cuda
# Out:
# '11.3'

# %%
from pytorch_forecasting.data.examples import get_stallion_data
data=get_stallion_data()

#add time idx
data['time_idx']=data['date'].dt.year*12+data['date'].dt.month
data['time_idx']-=data['time_idx'].min()

data['month']=data.date.dt.month.astype(str).astype('category')
data['log_volume']=np.log(data.volume+1e-8)
data['avg_volume_by_sku']=data.groupby(['time_idx','sku'], observed=True).volume.transform('mean')
data['avg_volume_by_agency']=data.groupby(['time_idx', 'agency'], observed=True).volume.transform('mean')

special_days=[
    'easter_day',
    'good_friday',
    'new_year',
    'christmas',
    'labor_day',
    'independence_day',
    'revolution_day_memorial',
    'regional_games',
    'fifa_u_17_world_cup',
    'football_gold_cup',
    'beer_capital',
    'music_fest',
]
data[special_days]=data[special_days].apply(lambda x: x.map({0: "-", 1: x.name})).astype('category')
data.sample(10, random_state=521)
# Out:
#           agency     sku     volume       date  industry_volume  soda_volume  \
# 291    Agency_25  SKU_03     0.5076 2013-01-01        492612703    718394219
# 871    Agency_29  SKU_02     8.7480 2015-01-01        498567142    762225057
# 19532  Agency_47  SKU_01     4.9680 2013-09-01        454252482    789624076
# 2089   Agency_53  SKU_07    21.6825 2013-10-01        480693900    791658684
# 9755   Agency_17  SKU_02   960.5520 2015-03-01        515468092    871204688
# 7561   Agency_05  SKU_03  1184.6535 2014-02-01        425528909    734443953
# 19204  Agency_11  SKU_05     5.5593 2017-08-01        623319783   1049868815
# 8781   Agency_48  SKU_04  4275.1605 2013-03-01        509281531    892192092
# 2540   Agency_07  SKU_21     0.0000 2015-10-01        544203593    761469815
# 12084  Agency_21  SKU_03    46.3608 2017-04-01        589969396    940912941
#
#        avg_max_temp  price_regular  price_actual    discount  ...  \
# 291       25.845238    1264.162234   1152.473405  111.688829  ...
# 871       27.584615    1316.098485   1296.804924   19.293561  ...
# 19532     30.665957    1269.250000   1266.490490    2.759510  ...
# 2089      29.197727    1193.842373   1128.124395   65.717978  ...
# 9755      23.608120    1338.334248   1232.128069  106.206179  ...
# 7561      28.668254    1369.556376   1161.135214  208.421162  ...
# 19204     31.915385    1922.486644   1651.307674  271.178970  ...
# 8781      26.767857    1761.258209   1546.059670  215.198539  ...
# 2540      28.987755       0.000000      0.000000    0.000000  ...
# 12084     32.478910    1675.922116   1413.571789  262.350327  ...
#
#        football_gold_cup  beer_capital  music_fest discount_in_percent  \
# 291                    -             -           -            8.835008
# 871                    -             -           -            1.465966
# 19532                  -             -           -            0.217413
# 2089                   -  beer_capital           -            5.504745
# 9755                   -             -  music_fest            7.935699
# 7561                   -             -           -           15.218151
# 19204                  -             -           -           14.105636
# 8781                   -             -  music_fest           12.218455
# 2540                   -             -           -            0.000000
# 12084                  -             -           -           15.654088
#
#       timeseries time_idx month log_volume avg_volume_by_sku  \
# 291          228        0     1  -0.678062       1225.306376
# 871          177       24     1   2.168825       1634.434615
# 19532        322        8     9   1.603017       2625.472644
# 2089         240        9    10   3.076505         38.529107
# 9755         259       26     3   6.867508       2143.677462
# 7561          21       13     2   7.077206       1566.643589
# 19204         17       55     8   1.715472       1385.225478
# 8781         151        2     3   8.360577       1757.950603
# 2540         300       33    10 -18.420681          0.000000
# 12084        181       51     4   3.836454       2034.293024
#
#       avg_volume_by_agency
# 291              99.650400
# 871              11.397086
# 19532            48.295650
# 2089           2511.035175
# 9755            396.022140
# 7561           1881.866367
# 19204           109.699200
# 8781           1925.272108
# 2540           2418.719550
# 12084           109.381800
#
# [10 rows x 31 columns]

# %%
data.query('sku=="SKU_01"').set_index('date').volume.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data.describe()
# Out:
#              volume  industry_volume   soda_volume  avg_max_temp  \
# count  21000.000000     2.100000e+04  2.100000e+04  21000.000000
# mean    1492.403982     5.439214e+08  8.512000e+08     28.612404
# std     2711.496882     6.288022e+07  7.824340e+07      3.972833
# min        0.000000     4.130518e+08  6.964015e+08     16.731034
# 25%        8.272388     5.090553e+08  7.890880e+08     25.374816
# 50%      158.436000     5.512000e+08  8.649196e+08     28.479272
# 75%     1774.793475     5.893715e+08  9.005551e+08     31.568405
# max    22526.610000     6.700157e+08  1.049869e+09     45.290476
#
#        price_regular  price_actual      discount  avg_population_2017  \
# count   21000.000000  21000.000000  21000.000000         2.100000e+04
# mean     1451.536344   1267.347450    184.374146         1.045065e+06
# std       683.362417    587.757323    257.469968         9.291926e+05
# min         0.000000  -3121.690141      0.000000         1.227100e+04
# 25%      1311.547158   1178.365653     54.935108         6.018900e+04
# 50%      1495.174592   1324.695705    138.307225         1.232242e+06
# 75%      1725.652080   1517.311427    272.298630         1.729177e+06
# max     19166.625000   4925.404000  19166.625000         3.137874e+06
#
#        avg_yearly_household_income_2017  discount_in_percent   timeseries  \
# count                      21000.000000         21000.000000  21000.00000
# mean                      151073.494286            10.574884    174.50000
# std                        50409.593114             9.590813    101.03829
# min                        90240.000000             0.000000      0.00000
# 25%                       110057.000000             3.749628     87.00000
# 50%                       131411.000000             8.948990    174.50000
# 75%                       206553.000000            15.647058    262.00000
# max                       247220.000000           226.740147    349.00000
#
#            time_idx    log_volume  avg_volume_by_sku  avg_volume_by_agency
# count  21000.000000  21000.000000       21000.000000          21000.000000
# mean      29.500000      2.464118        1492.403982           1492.403982
# std       17.318515      8.178218        1051.790829           1328.239698
# min        0.000000    -18.420681           0.000000              0.000000
# 25%       14.750000      2.112923         932.285496            113.420250
# 50%       29.500000      5.065351        1402.305264           1730.529771
# 75%       44.250000      7.481439        2195.362302           2595.316500
# max       59.000000     10.022453        4332.363750           5884.717375

# %%
max_prediction_length=6
max_encoder_length=24
traning_cutoff=data['time_idx'].max()-max_prediction_length

training=TimeSeriesDataSet(
    data[lambda x: x.time_idx <= traning_cutoff],
    time_idx='time_idx',
    target='volume',
    group_ids=['agency','sku'],
    min_encoder_length=max_encoder_length//2,
    max_encoder_length=max_encoder_length,
    min_prediction_length=1,
    max_prediction_length=max_prediction_length,
    static_categoricals=['agency','sku'],
    static_reals=['avg_population_2017','avg_yearly_household_income_2017'],
    time_varying_known_categoricals=['special_days','month'],
    variable_groups={'special_days':special_days},
    time_varying_known_reals=['time_idx','price_regular','discount_in_percent'],
    time_varying_unknown_categoricals=[],
    time_varying_unknown_reals=[
        'volume',
        'log_volume',
        'industry_volume',
        'soda_volume',
        'avg_max_temp',
        'avg_volume_by_agency',
        'avg_volume_by_sku',
    ],
    target_normalizer=GroupNormalizer(
        groups=['agency','sku'],transformation='softplus'
    ),
    add_relative_time_idx=True,
    add_target_scales=True,
    add_encoder_length=True,
)

validation=TimeSeriesDataSet.from_dataset(training, data, predict=True, stop_randomization=True)

batch_size=128
train_dataloader=training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader=validation.to_dataloader(train=False, batch_size=batch_size*10, num_workers=0)

# %%
actuals=torch.cat([y for x, (y, weight) in iter(val_dataloader)])
baseline_predictions=Baseline().predict(val_dataloader)
(actuals-baseline_predictions).abs().mean().item()
# Out:
# 293.0088195800781

# %%
pl.seed_everything(42)
trainer=pl.Trainer(
    gpus=0,
    gradient_clip_val=0.1,
)

tft=TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=0.03,
    hidden_size=16,
    attention_head_size=1,
    dropout=0.1,
    hidden_continuous_size=8,
    output_size=7,
    loss=QuantileLoss(),
    reduce_on_plateau_patience=4,
)
print(f'Number of parameters in network: {tft.size()/1e3:.1f}k')
# Out:
# Global seed set to 42
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Number of parameters in network: 29.7k

# %%
res=trainer.tuner.lr_find(
    tft,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
    max_lr=10.0,
    min_lr=1e-6,
)
print(f'suggested learning rate: {res.suggestion()}')
fig=res.plot(show=True, suggest=True)
fig.show()
# Out:
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:1079: LightningDeprecationWarning: `trainer.tune(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.tune(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# Global seed set to 42
# Finding best initial lr: 100%|████████████████████████████████████████████████████████| 100/100 [00:27<00:00,  3.76it/s]Restoring states from the checkpoint path at /root/star/kkt/lr_find_temp_model_b787d0cb-127e-41ae-8925-4eee5983c09e.ckpt
# Finding best initial lr: 100%|████████████████████████████████████████████████████████| 100/100 [00:27<00:00,  3.69it/s]
# suggested learning rate: 5.888436553555889e-06

# %%
early_stop_callback=EarlyStopping(monitor='val_loss', min_delta=1e-4,patience=10,verbose=False, mode='min')
lr_logger=LearningRateMonitor()
logger=TensorBoardLogger('lightning_logs')

trainer=pl.Trainer(
    max_epochs=30,
    gpus=0,
    weights_summary='top',
    gradient_clip_val=0.1,
    limit_train_batches=30,
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)

tft=TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=0.03,
    hidden_size=16,
    attention_head_size=1,
    dropout=0.1,
    hidden_continuous_size=8,
    output_size=7,
    loss=QuantileLoss(),
    log_interval=10,
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Number of parameters in network: 29.7k

# %%
trainer.fit(
    tft,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 1.3 K
# 3  | prescalers                         | ModuleDict                      | 256
# 4  | static_variable_selection          | VariableSelectionNetwork        | 3.4 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 8.0 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 2.7 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 29.7 K    Trainable params
# 0         Non-trainable params
# 29.7 K    Total params
# 0.119     Total estimated model params size (MB)
# Global seed set to 42
# Epoch 0:  97%|██████████████████████████████▉ | 30/31 [00:09<00:00,  3.30it/s, loss=111, v_num=1, train_loss_step=86.40]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|████████████████| 31/31 [00:10<00:00,  3.08it/s, loss=111, v_num=1, train_loss_step=86.40, val_loss=128.0]
# Epoch 1:  97%|▉| 30/31 [00:09<00:00,  3.33it/s, loss=77.5, v_num=1, train_loss_step=74.70, val_loss=128.0, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 31/31 [00:09<00:00,  3.12it/s, loss=77.5, v_num=1, train_loss_step=74.70, val_loss=106.0, train_loss_ep
# Epoch 2:  97%|▉| 30/31 [00:09<00:00,  3.32it/s, loss=72.3, v_num=1, train_loss_step=77.30, val_loss=106.0, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 31/31 [00:10<00:00,  2.91it/s, loss=72.3, v_num=1, train_loss_step=77.30, val_loss=102.0, train_loss_ep
# Epoch 3:  97%|▉| 30/31 [00:09<00:00,  3.32it/s, loss=69.7, v_num=1, train_loss_step=90.50, val_loss=102.0, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 31/31 [00:09<00:00,  3.10it/s, loss=69.7, v_num=1, train_loss_step=90.50, val_loss=100.0, train_loss_ep
# Epoch 4:  97%|▉| 30/31 [00:10<00:00,  3.00it/s, loss=69.5, v_num=1, train_loss_step=76.10, val_loss=100.0, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 31/31 [00:11<00:00,  2.71it/s, loss=69.5, v_num=1, train_loss_step=76.10, val_loss=97.00, train_loss_ep
# Epoch 5:  97%|▉| 30/31 [00:09<00:00,  3.22it/s, loss=66.2, v_num=1, train_loss_step=68.70, val_loss=97.00, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 31/31 [00:10<00:00,  3.03it/s, loss=66.2, v_num=1, train_loss_step=68.70, val_loss=84.90, train_loss_ep
# Epoch 6:  97%|▉| 30/31 [00:08<00:00,  3.44it/s, loss=63.8, v_num=1, train_loss_step=74.00, val_loss=84.90, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 31/31 [00:09<00:00,  3.23it/s, loss=63.8, v_num=1, train_loss_step=74.00, val_loss=84.90, train_loss_ep
# Epoch 7:  97%|▉| 30/31 [00:08<00:00,  3.36it/s, loss=60, v_num=1, train_loss_step=59.70, val_loss=84.90, train_loss_epoc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 31/31 [00:09<00:00,  3.15it/s, loss=60, v_num=1, train_loss_step=59.70, val_loss=81.40, train_loss_epoc
# Epoch 8:  97%|▉| 30/31 [00:08<00:00,  3.41it/s, loss=58, v_num=1, train_loss_step=53.20, val_loss=81.40, train_loss_epoc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 31/31 [00:09<00:00,  3.18it/s, loss=58, v_num=1, train_loss_step=53.20, val_loss=82.70, train_loss_epoc
# Epoch 9:  97%|▉| 30/31 [00:09<00:00,  3.19it/s, loss=54.2, v_num=1, train_loss_step=49.40, val_loss=82.70, train_loss_ep
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 31/31 [00:10<00:00,  2.86it/s, loss=54.2, v_num=1, train_loss_step=49.40, val_loss=80.00, train_loss_ep
# Epoch 10:  97%|▉| 30/31 [00:08<00:00,  3.36it/s, loss=58.5, v_num=1, train_loss_step=56.90, val_loss=80.00, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 31/31 [00:09<00:00,  3.15it/s, loss=58.5, v_num=1, train_loss_step=56.90, val_loss=76.40, train_loss_e
# Epoch 11:  97%|▉| 30/31 [00:08<00:00,  3.39it/s, loss=51.1, v_num=1, train_loss_step=51.10, val_loss=76.40, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 31/31 [00:09<00:00,  3.17it/s, loss=51.1, v_num=1, train_loss_step=51.10, val_loss=78.20, train_loss_e
# Epoch 12:  97%|▉| 30/31 [00:08<00:00,  3.37it/s, loss=51.9, v_num=1, train_loss_step=51.30, val_loss=78.20, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 31/31 [00:09<00:00,  3.15it/s, loss=51.9, v_num=1, train_loss_step=51.30, val_loss=75.60, train_loss_e
# Epoch 13:  97%|▉| 30/31 [00:09<00:00,  3.12it/s, loss=49.5, v_num=1, train_loss_step=41.90, val_loss=75.60, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 31/31 [00:10<00:00,  2.93it/s, loss=49.5, v_num=1, train_loss_step=41.90, val_loss=73.60, train_loss_e
# Epoch 14:  97%|▉| 30/31 [00:08<00:00,  3.38it/s, loss=48.1, v_num=1, train_loss_step=41.50, val_loss=73.60, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 31/31 [00:09<00:00,  3.16it/s, loss=48.1, v_num=1, train_loss_step=41.50, val_loss=74.80, train_loss_e
# Epoch 15:  97%|▉| 30/31 [00:09<00:00,  3.33it/s, loss=52.6, v_num=1, train_loss_step=58.30, val_loss=74.80, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 31/31 [00:10<00:00,  3.08it/s, loss=52.6, v_num=1, train_loss_step=58.30, val_loss=74.60, train_loss_e
# Epoch 16:  97%|▉| 30/31 [00:08<00:00,  3.40it/s, loss=49.6, v_num=1, train_loss_step=45.60, val_loss=74.60, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 31/31 [00:09<00:00,  3.16it/s, loss=49.6, v_num=1, train_loss_step=45.60, val_loss=80.40, train_loss_e
# Epoch 17:  97%|▉| 30/31 [00:09<00:00,  3.06it/s, loss=50.3, v_num=1, train_loss_step=49.20, val_loss=80.40, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 31/31 [00:10<00:00,  2.89it/s, loss=50.3, v_num=1, train_loss_step=49.20, val_loss=79.20, train_loss_e
# Epoch 18:  97%|▉| 30/31 [00:08<00:00,  3.48it/s, loss=50.1, v_num=1, train_loss_step=68.40, val_loss=79.20, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 31/31 [00:09<00:00,  3.24it/s, loss=50.1, v_num=1, train_loss_step=68.40, val_loss=78.10, train_loss_e
# Epoch 19:  97%|▉| 30/31 [00:08<00:00,  3.38it/s, loss=48, v_num=1, train_loss_step=57.40, val_loss=78.10, train_loss_epo
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 31/31 [00:09<00:00,  3.15it/s, loss=48, v_num=1, train_loss_step=57.40, val_loss=77.80, train_loss_epo
# Epoch 20:  97%|▉| 30/31 [00:09<00:00,  3.32it/s, loss=45.2, v_num=1, train_loss_step=58.50, val_loss=77.80, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 31/31 [00:09<00:00,  3.10it/s, loss=45.2, v_num=1, train_loss_step=58.50, val_loss=79.10, train_loss_e
# Epoch 21:  97%|▉| 30/31 [00:08<00:00,  3.37it/s, loss=47.1, v_num=1, train_loss_step=51.00, val_loss=79.10, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 31/31 [00:09<00:00,  3.15it/s, loss=47.1, v_num=1, train_loss_step=51.00, val_loss=77.80, train_loss_e
# Epoch 22:  97%|▉| 30/31 [00:09<00:00,  3.02it/s, loss=46.6, v_num=1, train_loss_step=39.60, val_loss=77.80, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 31/31 [00:10<00:00,  2.86it/s, loss=46.6, v_num=1, train_loss_step=39.60, val_loss=76.30, train_loss_e
# Epoch 23:  97%|▉| 30/31 [00:08<00:00,  3.34it/s, loss=45.8, v_num=1, train_loss_step=58.20, val_loss=76.30, train_loss_e
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                 | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 31/31 [00:09<00:00,  3.12it/s, loss=45.8, v_num=1, train_loss_step=58.20, val_loss=77.00, train_loss_e
# Epoch 23: 100%|█| 31/31 [00:10<00:00,  2.96it/s, loss=45.8, v_num=1, train_loss_step=58.20, val_loss=77.00, train_loss_e

# %%
import pickle

from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# create study
study = optimize_hyperparameters(
    train_dataloader,
    val_dataloader,
    model_path="optuna_test",
    n_trials=200,
    max_epochs=50,
    gradient_clip_val_range=(0.01, 1.0),
    hidden_size_range=(8, 128),
    hidden_continuous_size_range=(8, 128),
    attention_head_size_range=(1, 4),
    learning_rate_range=(0.001, 0.1),
    dropout_range=(0.1, 0.3),
    trainer_kwargs=dict(limit_train_batches=30),
    reduce_on_plateau_patience=4,
    use_learning_rate_finder=False,  # use Optuna to find ideal learning rate or use in-built learning rate finder
)

# save study results - also we can resume tuning at a later point in time
with open("test_study.pkl", "wb") as fout:
    pickle.dump(study, fout)

# show best hyperparameters
print(study.best_trial.params)
# Out:
# [I 2022-01-13 00:54:54,333] A new study created in memory with name: no-name-5616fe52-325f-45b4-ad47-0f12a33a3832
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:00:19,738] Trial 0 finished with value: 83.84371948242188 and parameters: {'gradient_clip_val': 0.21545386653399248, 'hidden_size': 89, 'dropout': 0.18688164570408325, 'hidden_continuous_size': 58, 'attention_head_size': 4, 'learning_rate': 0.03777132853396612}. Best is trial 0 with value: 83.84371948242188.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:05:26,821] Trial 1 finished with value: 83.12645721435547 and parameters: {'gradient_clip_val': 0.5020637819906569, 'hidden_size': 34, 'dropout': 0.13027834478615202, 'hidden_continuous_size': 9, 'attention_head_size': 3, 'learning_rate': 0.023628012714586692}. Best is trial 1 with value: 83.12645721435547.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:05:39,212] Trial 2 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:05:51,669] Trial 3 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:06:02,902] Trial 4 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:06:15,424] Trial 5 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:08:10,193] Trial 6 pruned. Trial was pruned at epoch 16.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:08:25,941] Trial 7 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:09:04,391] Trial 8 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:09:19,938] Trial 9 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:09:35,307] Trial 10 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:10:13,147] Trial 11 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:12:25,785] Trial 12 pruned. Trial was pruned at epoch 16.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:12:40,845] Trial 13 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:12:56,218] Trial 14 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:13:09,949] Trial 15 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:13:22,981] Trial 16 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:13:35,824] Trial 17 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:13:48,556] Trial 18 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:14:20,911] Trial 19 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:14:34,063] Trial 20 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:14:46,262] Trial 21 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:14:59,904] Trial 22 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:15:13,034] Trial 23 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:15:45,494] Trial 24 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:16:18,304] Trial 25 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:16:30,989] Trial 26 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:16:43,891] Trial 27 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:16:56,661] Trial 28 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:17:09,465] Trial 29 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:17:22,919] Trial 30 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:17:36,286] Trial 31 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:18:09,206] Trial 32 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 01:19:59,936] Trial 33 pruned. Trial was pruned at epoch 16.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# ...
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:33:53,574] Trial 188 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:34:06,798] Trial 189 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:34:19,917] Trial 190 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:34:33,205] Trial 191 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:34:46,328] Trial 192 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:34:59,493] Trial 193 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:35:12,750] Trial 194 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:35:45,412] Trial 195 pruned. Trial was pruned at epoch 4.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:35:58,701] Trial 196 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:36:12,050] Trial 197 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:36:25,056] Trial 198 pruned. Trial was pruned at epoch 1.
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:90: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   rank_zero_deprecation(
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:167: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /root/anaconda3/envs/kkt/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py:735: LightningDeprecationWarning: `trainer.fit(train_dataloader)` is deprecated in v1.4 and will be removed in v1.6. Use `trainer.fit(train_dataloaders)` instead. HINT: added 's'
#   rank_zero_deprecation(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Global seed set to 42
# [I 2022-01-13 02:36:38,149] Trial 199 pruned. Trial was pruned at epoch 1.
# {'gradient_clip_val': 0.43475024499694975, 'hidden_size': 81, 'dropout': 0.28829375296397497, 'hidden_continuous_size': 77, 'attention_head_size': 3, 'learning_rate': 0.0272778209797217}

# %%
# load the best model according to the validation loss
# (given that we use early stopping, this is not necessarily the last epoch)
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)

# %%
# calcualte mean absolute error on validation set
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_tft.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(262.4135)

# %%
# raw predictions are a dictionary from which all kind of information including quantiles can be extracted
raw_predictions, x = best_tft.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(20):  # plot 10 examples
    best_tft.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True)

# %%
# calcualte metric by which to display
predictions = best_tft.predict(val_dataloader)
mean_losses = SMAPE(reduction="none")(predictions, actuals).mean(1)
indices = mean_losses.argsort(descending=True)  # sort losses
for idx in range(10):  # plot 10 examples
    best_tft.plot_prediction(
        x, raw_predictions, idx=indices[idx], add_loss_to_title=SMAPE(quantiles=best_tft.loss.quantiles)
    )

# %%
predictions, x = best_tft.predict(val_dataloader, return_x=True)
predictions_vs_actuals = best_tft.calculate_prediction_actual_by_variable(x, predictions)
best_tft.plot_prediction_actual_by_variable(predictions_vs_actuals);

# %%
interpretation = best_tft.interpret_output(raw_predictions, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# {'attention': <Figure size 432x288 with 1 Axes>,
#  'static_variables': <Figure size 504x270 with 1 Axes>,
#  'encoder_variables': <Figure size 504x378 with 1 Axes>,
#  'decoder_variables': <Figure size 504x252 with 1 Axes>}

# %%
!
